# %% [markdown]
# ## Índice<a name="indice"></a>
# * [1 Prepocesado de datos](#1)
#     * [1.1 Importación de librerías](#1_1)
#     * [1.2 Carga del Dataset](#1_2)
# * [2 Análisis Exploratorio de datos](#2)
#     * [2.1 Estadísitcas descriptivas](#2_1)
#         * [2.1.1 Medidas de tendencia central](#2_1_1)
#         * [2.1.2 Frecuencias](#2_1_2)
#         * [2.1.3 Agrupaciones](#2_1_3)
#         * [2.1.4 Filtros](#2_1_4)
#         * [2.1.5 Distribución normal](#2_1_5)
#         * [2.1.6 Media](#2_1_6)
#         * [2.1.7 Mediana](#2_1_7)
#         * [2.1.8 Moda](#2_1_8)
#         * [2.1.9 Varianza](#2_1_9)
#         * [2.1.10 Desviación Típica/Estándar](#2_1_10)
#         * [2.1.11 Quartiles](#2_1_11)
#         * [2.1.12 Rango Intercuartílico IQR](#2_1_12)
#     * [2.2 Detección de Outliers](#2_2)
#     * [2.3 Detección de correlaciones](#2_3)
# * [3 Diseño de características](#3)
#     * [3.1 Tratamiento de datos nulos](#3_1)
#     * [3.2 Transformación de características](#3_2)
#     * [3.3 Selección de características relevante](#3_3)
#     * [3.4 Tratamiento de outliers](#3_4)
#     * [3.5 Tratamiento de correlación](#3_5)
#     * [3.6 Normalización](#3_6)

# %% [markdown]
# # 1 Prepocesado de datos<a name="1"></a>
# [Índice](#indice)
#
# https://archive.ics.uci.edu/ml/datasets/student+performance
#
# 1 school - student's school (binary: "GP" - Gabriel Pereira or "MS" - Mousinho da Silveira)
#
# 2 sex - student's sex (binary: "F" - female or "M" - male)
#
# 3 age - student's age (numeric: from 15 to 22)
#
# 4 address - student's home address type (binary: "U" - urban or "R" - rural)
#
# 5 famsize - family size (binary: "LE3" - less or equal to 3 or "GT3" - greater than 3)
#
# 6 Pstatus - parent's cohabitation status (binary: "T" - living together or "A" - apart)
#
# 7 Medu - mother's education (numeric: 0 - none,  1 - primary education (4th grade), 2 – 5th to 9th
# grade, 3 – secondary education or 4 – higher education)
#
# 8 Fedu - father's education (numeric: 0 - none,  1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
#
# 9 Mjob - mother's job (nominal: "teacher", "health" care related, civil "services" (e.g. administrative or police), "at_home" or "other")
#
# 10 Fjob - father's job (nominal: "teacher", "health" care related, civil "services" (e.g. administrative or police), "at_home" or "other")
#
# 11 reason - reason to choose this school (nominal: close to "home", school "reputation", "course" preference or "other")
#
# 12 guardian - student's guardian (nominal: "mother", "father" or "other")
#
# 13 traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
#
# 14 studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
#
# 15 failures - number of past class failures (numeric: n if 1<=n<3, else 4)
#
# 16 schoolsup - extra educational support (binary: yes or no)
#
# 17 famsup - family educational support (binary: yes or no)
#
# 18 paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
#
# 19 activities - extra-curricular activities (binary: yes or no)
#
# 20 nursery - attended nursery school (binary: yes or no)
#
# 21 higher - wants to take higher education (binary: yes or no)
#
# 22 internet - Internet access at home (binary: yes or no)
#
# 23 romantic - with a romantic relationship (binary: yes or no)
#
# 24 famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
#
# 25 freetime - free time after school (numeric: from 1 - very low to 5 - very high)
#
# 26 goout - going out with friends (numeric: from 1 - very low to 5 - very high)
#
# 27 Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
# 28 Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
# 29 health - current health status (numeric: from 1 - very bad to 5 - very good)
#
# 30 absences - number of school absences (numeric: from 0 to 93)
#
# 31 G1 - first period grade (numeric: from 0 to 20)
#
# 31 G2 - second period grade (numeric: from 0 to 20)
#
# 32 G3 - final grade (numeric: from 0 to 20, output target)

# %% [markdown]
# ## 1.1 Importación de librerías<a name="1_1"></a>
# [Índice](#indice)

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ## 1.2 Carga del dataset<a name="1_2"></a>
# [Índice](#indice)

# %%
# Cargar fichero en un dataframe
df = pd.read_csv('student/student-mat.csv',delimiter=';')

# %%
# Mostrar datos
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
# Exportar dataframe a csv
#df.to_csv('student/student2.csv')

# %% [markdown]
# # 2 Análisis Exploratorio de datos<a name="2"></a>
# [Índice](#indice)

# %%
#Dimensionalidad
df.shape
# Out:
# (395, 33)

# %%
print(f"Nº Filas:{df.shape[0]}\nNº Columnas:{df.shape[1]}")
# Out:
# Nº Filas:395
# Nº Columnas:33

# %%
#Nº de filas
len(df)
# Out:
# 395

# %%
# 5 primeras filas
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
# 2 primeras filas
df.head(2)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home  teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home    other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences G1 G2 G3
# 0      4        3      4     1     1      3        6  5  6  6
# 1      5        3      3     1     1      3        4  5  5  6
#
# [2 rows x 33 columns]

# %%
# 5 Últimas filas
df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %%
# 2 últimas
df.tail(2)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob     Fjob  \
# 393     MS   M   18       R     LE3       T     3     2  services    other
# 394     MS   M   19       U     LE3       T     1     1     other  at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [2 rows x 33 columns]

# %%
# Nombres de columnas
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
# Tipos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
# Tipo de df
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.shape)
# Out:
# tuple

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
# Tipo de una columna de df
type(df.school)
# Out:
# pandas.core.series.Series

# %%
type(df['school'])
# Out:
# pandas.core.series.Series

# %%
# Seleccionar columnas
df.school
# Out:
# 0      GP
# 1      GP
# 2      GP
# 3      GP
# 4      GP
#        ..
# 390    MS
# 391    MS
# 392    MS
# 393    MS
# 394    MS
# Name: school, Length: 395, dtype: object

# %%
df['school']
# Out:
# 0      GP
# 1      GP
# 2      GP
# 3      GP
# 4      GP
#        ..
# 390    MS
# 391    MS
# 392    MS
# 393    MS
# 394    MS
# Name: school, Length: 395, dtype: object

# %%
# seleccionar dos o más columnas
df[['school','sex']]
# Out:
#     school sex
# 0       GP   F
# 1       GP   F
# 2       GP   F
# 3       GP   F
# 4       GP   F
# ..     ...  ..
# 390     MS   M
# 391     MS   M
# 392     MS   M
# 393     MS   M
# 394     MS   M
#
# [395 rows x 2 columns]

# %%
#seleccionar columnas por tipo de datos
df.select_dtypes(include=object)
# Out:
#     school sex address famsize Pstatus      Mjob      Fjob  reason guardian  \
# 0       GP   F       U     GT3       A   at_home   teacher  course   mother
# 1       GP   F       U     GT3       T   at_home     other  course   father
# 2       GP   F       U     LE3       T   at_home     other   other   mother
# 3       GP   F       U     GT3       T    health  services    home   mother
# 4       GP   F       U     GT3       T     other     other    home   father
# ..     ...  ..     ...     ...     ...       ...       ...     ...      ...
# 390     MS   M       U     LE3       A  services  services  course    other
# 391     MS   M       U     LE3       T  services  services  course   mother
# 392     MS   M       R     GT3       T     other     other  course    other
# 393     MS   M       R     LE3       T  services     other  course   mother
# 394     MS   M       U     LE3       T     other   at_home  course   father
#
# ...

# %%
#Seleccionar por más de un tipo
df.select_dtypes(include=['int64','float64'])
# Out:
#      age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 0     18     4     4           2          2         0       4         3
# 1     17     1     1           1          2         0       5         3
# 2     15     1     1           1          2         3       4         3
# 3     15     4     2           1          3         0       3         2
# 4     16     3     3           1          2         0       4         3
# ..   ...   ...   ...         ...        ...       ...     ...       ...
# 390   20     2     2           1          2         2       5         5
# 391   17     3     1           2          1         0       2         4
# 392   21     1     1           1          1         3       5         5
# 393   18     3     2           3          1         0       4         4
# 394   19     1     1           1          1         0       3         2
#
#      goout  Dalc  Walc  health  absences  G1  G2  G3
# ...

# %%
df.select_dtypes(exclude=object)
# Out:
#      age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 0     18     4     4           2          2         0       4         3
# 1     17     1     1           1          2         0       5         3
# 2     15     1     1           1          2         3       4         3
# 3     15     4     2           1          3         0       3         2
# 4     16     3     3           1          2         0       4         3
# ..   ...   ...   ...         ...        ...       ...     ...       ...
# 390   20     2     2           1          2         2       5         5
# 391   17     3     1           2          1         0       2         4
# 392   21     1     1           1          1         3       5         5
# 393   18     3     2           3          1         0       4         4
# 394   19     1     1           1          1         0       3         2
#
#      goout  Dalc  Walc  health  absences  G1  G2  G3
# ...

# %% [markdown]
# ## 2.1Estadísticas descriptivas<a name="2_1"></a>
# [Índice](#indice)

# %% [markdown]
# ### 2.1.1 Medidas de tendencia central<a name="2_1_1"></a>
# [Índice](#indice)

# %%
# Muestra medidas estadísticas de las columnas de tipo numérico
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
# Mostrar estadísticas de columas no numéricas
df.describe(include=object)
# Out:
#        school  sex address famsize Pstatus   Mjob   Fjob  reason guardian  \
# count     395  395     395     395     395    395    395     395      395
# unique      2    2       2       2       2      5      5       4        3
# top        GP    F       U     GT3       T  other  other  course   mother
# freq      349  208     307     281     354    141    217     145      273
#
#        schoolsup famsup paid activities nursery higher internet romantic
# count        395    395  395        395     395    395      395      395
# unique         2      2    2          2       2      2        2        2
# top           no    yes   no        yes     yes    yes      yes       no
# freq         344    242  214        201     314    375      329      263

# %%
#Mostrar estadísticas de todos los tipos de datos
df.describe(include='all')
# Out:
#        school  sex         age address famsize Pstatus        Medu  \
# count     395  395  395.000000     395     395     395  395.000000
# unique      2    2         NaN       2       2       2         NaN
# top        GP    F         NaN       U     GT3       T         NaN
# freq      349  208         NaN     307     281     354         NaN
# mean      NaN  NaN   16.696203     NaN     NaN     NaN    2.749367
# std       NaN  NaN    1.276043     NaN     NaN     NaN    1.094735
# min       NaN  NaN   15.000000     NaN     NaN     NaN    0.000000
# 25%       NaN  NaN   16.000000     NaN     NaN     NaN    2.000000
# 50%       NaN  NaN   17.000000     NaN     NaN     NaN    3.000000
# 75%       NaN  NaN   18.000000     NaN     NaN     NaN    4.000000
# max       NaN  NaN   22.000000     NaN     NaN     NaN    4.000000
#
#               Fedu   Mjob   Fjob  ...      famrel    freetime       goout  \
# count   395.000000    395    395  ...  395.000000  395.000000  395.000000
# ...

# %%
# Estadísticas de un conjunto de columnas
df[['G1','G2','G3']].describe()
# Out:
#                G1          G2          G3
# count  395.000000  395.000000  395.000000
# mean    10.908861   10.713924   10.415190
# std      3.319195    3.761505    4.581443
# min      3.000000    0.000000    0.000000
# 25%      8.000000    9.000000    8.000000
# 50%     11.000000   11.000000   11.000000
# 75%     13.000000   13.000000   14.000000
# max     19.000000   19.000000   20.000000

# %%
# Estadística de una columna numérica
df.age.describe()
df['age'].describe()
# Out:
# count    395.000000
# mean      16.696203
# std        1.276043
# min       15.000000
# 25%       16.000000
# 50%       17.000000
# 75%       18.000000
# max       22.000000
# Name: age, dtype: float64

# %%
# Valores únicos de columna no numérica
df.school.unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %%
# Nº de valores de columna no numérica
df.school.nunique()
# Out:
# 2

# %% [markdown]
# ### 2.1.2 Frecuencias<a name="2_1_2"></a>
# [Índice](#indice)

# %%
# Suele hacerse para variables object
df['school'].value_counts()
# Out:
# GP    349
# MS     46
# Name: school, dtype: int64

# %%
# Idem con porcentajes
df['school'].value_counts()/len(df)*100
df['school'].value_counts()/df.shape[0]*100
# Out:
# GP    88.35443
# MS    11.64557
# Name: school, dtype: float64

# %%
# Frecuencias de columna numérica
print(df.age.value_counts())
print(df.age.value_counts()/len(df)*100)
# Out:
# 16    104
# 17     98
# 18     82
# 15     82
# 19     24
# 20      3
# 22      1
# 21      1
# Name: age, dtype: int64
# 16    26.329114
# 17    24.810127
# 18    20.759494
# 15    20.759494
# 19     6.075949
# 20     0.759494
# 22     0.253165
# 21     0.253165
# Name: age, dtype: float64

# %%
# Idem ordenado por edad
print(df.age.value_counts().sort_index)
print(df.age.value_counts().sort_index()/len(df)*100)
# Out:
# <bound method Series.sort_index of 16    104
# 17     98
# 18     82
# 15     82
# 19     24
# 20      3
# 22      1
# 21      1
# Name: age, dtype: int64>
# 15    20.759494
# 16    26.329114
# 17    24.810127
# 18    20.759494
# 19     6.075949
# 20     0.759494
# 21     0.253165
# 22     0.253165
# Name: age, dtype: float64

# %%
# Analizar frecuencias con gráficas
# Ver Nº de alumnos por tipo de escula
df.school.value_counts().plot(kind='bar', title='Nº de alumnos por tipo de escuela')
# Out:
# <AxesSubplot:title={'center':'Nº de alumnos por tipo de escuela'}>

# %%
# Analizar frecuencias con gráficas
# Ver Nº de alumnos por tipo de escula
df.school.value_counts().plot(kind='pie', autopct='%0.2f%%', title='Nº de alumnos por tipo de escuela')
# Out:
# <AxesSubplot:title={'center':'Nº de alumnos por tipo de escuela'}, ylabel='school'>

# %%
# Mostrar Nº de alumnos por edad
df['age'].value_counts().sort_index().plot(kind='bar', title='Nº de alumnos por edad', xlabel='Edad')
# Out:
# <AxesSubplot:title={'center':'Nº de alumnos por edad'}, xlabel='Edad'>

# %%
# Gráficas con seaborn -> Hacer import!!
# Configuramos el tema
sns.set_theme(style='whitegrid')
ax=sns.catplot(x='age', kind='count', data=df)
ax.set(title='Nº de alumnos por edad')

# %%
# Mostrar Nº de alumnos por edad diferenciando por sexo
ax=sns.catplot(x='age', kind='count', hue='sex', data=df)
ax.set(title='Nº de alumnos por edad')

# %%
# Mostrar Nº de alumnos por edad diferenciando por sexo y tipo de escula
ax=sns.catplot(x='age', kind='count', hue='sex', row='school', data=df, aspect=2, margin_titles=True)
ax.set(title='Nº de alumnos por edad')

# %% [markdown]
# ### 2.1.3 Agrupaciones<a name="2_1_3"></a>
# [Índice](#indice)

# %%
# Hacer grupos por variable/s
# Suelen hacerse para variables categóricas
# Obetener las estadísticas agrupando por sexo
df.groupby('sex').describe()
# Out:
#        age                                                      Medu  \
#      count       mean       std   min   25%   50%   75%   max  count
# sex
# F    208.0  16.730769  1.201696  15.0  16.0  17.0  18.0  20.0  208.0
# M    187.0  16.657754  1.356181  15.0  16.0  16.0  18.0  22.0  187.0
#
#                ...    G2           G3                                       \
#          mean  ...   75%   max  count       mean       std  min  25%   50%
# sex            ...
# F    2.668269  ...  13.0  18.0  208.0   9.966346  4.622338  0.0  8.0  10.0
# M    2.839572  ...  14.0  19.0  187.0  10.914439  4.495297  0.0  9.0  11.0
#
#
#       75%   max
# sex
# F    13.0  19.0
# M    14.0  20.0
#
# [2 rows x 128 columns]

# %%
# Estadísticas de una variables(G1,G2,G3) agrupado por sexo
df.groupby('sex')[['G1','G2','G3']].describe()
# Out:
#         G1                                                      G2             \
#      count       mean       std  min  25%   50%   75%   max  count       mean
# sex
# F    208.0  10.620192  3.232530  4.0  8.0  10.0  13.0  19.0  208.0  10.389423
# M    187.0  11.229947  3.392839  3.0  9.0  11.0  14.0  19.0  187.0  11.074866
#
#      ...                 G3
#      ...   75%   max  count       mean       std  min  25%   50%   75%   max
# sex  ...
# F    ...  13.0  18.0  208.0   9.966346  4.622338  0.0  8.0  10.0  13.0  19.0
# M    ...  14.0  19.0  187.0  10.914439  4.495297  0.0  9.0  11.0  14.0  20.0
#
# [2 rows x 24 columns]

# %%
# Media de notas por sexo
df.groupby('sex')[['G1','G2','G3']].mean()
# Out:
#             G1         G2         G3
# sex
# F    10.620192  10.389423   9.966346
# M    11.229947  11.074866  10.914439

# %%
#GRupos de dos variables
#Medias de notas por sexo y escuela
df.groupby(['sex','school'])[['G1','G2','G3']].mean()
# Out:
#                    G1         G2         G3
# sex school
# F   GP      10.579235  10.398907   9.972678
#     MS      10.920000  10.320000   9.920000
# M   GP      11.337349  11.204819  11.060241
#     MS      10.380952  10.047619   9.761905

# %%
# GRupos usando gráficas de seaborn (barplot)
#Obtenemos la nota media de G3 por sexo
g3porSexo=df.groupby('sex')['G3'].mean()
g3porSexo
# Out:
# sex
# F     9.966346
# M    10.914439
# Name: G3, dtype: float64

# %%
# Convertimos g3porSexo en un dataframe con índice
g3porSexo = g3porSexo.reset_index()
g3porSexo
# Out:
#   sex         G3
# 0   F   9.966346
# 1   M  10.914439

# %%
#Pintar gráfica
ax=sns.barplot(x='sex',y='G3',data=g3porSexo)
ax.set(title='Nota media del tercer trimestre por sexo')
# Out:
# [Text(0.5, 1.0, 'Nota media del tercer trimestre por sexo')]

# %%
# Calculamos media
g3SexoEscuela = df.groupby(['sex','school'])['G3'].mean()
# Creamos df g3SexoEscuela
g3SexoEscuela =g3SexoEscuela.reset_index()

ax=sns.barplot(x='sex',y='G3', hue= 'school', data=g3SexoEscuela)
ax.set(title='Nota media del tercer trimestre por sexo y escuela')
# Out:
# [Text(0.5, 1.0, 'Nota media del tercer trimestre por sexo y escuela')]

# %% [markdown]
# ### 2.1.4 Filtros<a name="2_1_4"></a>
# [Índice](#indice)

# %%
# Valores del campo guardian
df['guardian'].value_counts()
# Out:
# mother    273
# father     90
# other      32
# Name: guardian, dtype: int64

# %%
# Obtener los datos donde la custodia no la tiene ni el padre ni la madre
filtro = df['guardian']=='other'
df[filtro]
#df[df['guardian']=='other']
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 14      GP   M   15       U     GT3       A     2     2     other     other
# 41      GP   M   15       U     LE3       T     4     4   teacher     other
# 127     GP   F   19       U     GT3       T     0     1   at_home     other
# 137     GP   F   16       U     GT3       A     3     3     other     other
# 152     GP   F   15       R     GT3       T     3     3  services  services
# 192     GP   M   17       U     GT3       T     1     2   at_home  services
# 210     GP   F   19       U     GT3       T     3     3     other     other
# 244     GP   F   18       U     GT3       T     2     1     other     other
# 251     GP   M   16       U     GT3       T     3     3   at_home     other
# 270     GP   F   19       U     GT3       T     3     3     other  services
# 296     GP   F   19       U     GT3       T     4     4    health     other
# ...

# %%
#Obtener notas (G1,G2 y G3) de los alumnos cuya custodia es other
df[filtro][['G1','G2','G3']]
# Out:
#      G1  G2  G3
# 14   14  16  16
# 41   12  12  12
# 127   7   8   9
# 137   4   0   0
# 152  10  10  10
# 192   7   8   8
# 210   8   8   8
# 244   7   0   0
# 251   7  10  10
# 270   9   9   9
# 296  10   9   0
# 297  10   8   8
# 304  15  14  13
# 305  14  12  12
# 306  17  18  18
# 307   8   9   8
# 309  12  10  10
# 310   9   9   0
# 311  14  12  13
# 312  13  11  11
# 313  13  10  11
# 314  15  13  13
# 315  13  11  11
# 333   8   8   0
# 336  14  13  13
# 340  11  12  11
# 350   8   7   8
# 353   8   8   8
# 370   7   7   9
# 376  15  14  15
# 390   9   9   9
# 392  10   8   7

# %%
#Obtener la nota media de (G1,G2 y G3) de los alumnos cuya custodia es other
df[filtro][['G1','G2','G3']].mean()
# Out:
# G1    10.56250
# G2     9.78125
# G3     9.06250
# dtype: float64

# %%
#Obtener la nota media de (G1,G2 y G3) de los alumnos cuya custodia es other por sexo
df[filtro].groupby('sex')[['G1','G2','G3']].mean()
# Out:
#             G1         G2         G3
# sex
# F    10.500000   9.150000   8.100000
# M    10.666667  10.833333  10.666667

# %%
# Obtener el nº de alumnos que aprueban el tercer trimestre
filtroAprobados = df['G3']>=10
#Datos de alumnos aprobados
df[filtroAprobados]
#Nº de alumnos aprobados
len(df[filtroAprobados])
# Out:
# 265

# %%
# Función loc: Aplica un filtro y selecciona una columna
# Mostrar notas de alumnos aprobados G3 con función loc
print(f"Notas de alumnos aprobados\n{df.loc[filtroAprobados,'G3']}")
# Nota media de los alumnos aprobados G3
print(f"Notas media alumnos aprobados{df.loc[filtroAprobados,'G3'].mean()}")
# Out:
# Notas de alumnos aprobados
# 2      10
# 3      15
# 4      10
# 5      15
# 6      11
#        ..
# 380    14
# 382    10
# 385    10
# 391    16
# 393    10
# Name: G3, Length: 265, dtype: int64
# Notas media alumnos aprobados12.883018867924529

# %%
# Notas medias de los aprobados
df.loc[filtroAprobados,['G1','G2','G3']].mean()
# Out:
# G1    12.452830
# G2    12.622642
# G3    12.883019
# dtype: float64

# %% [markdown]
# ### 2.1.5 Distribución Normal<a name="2_1_5"></a>
# [Índice](#indice)

# %%
# Ver si G3 sigue una distribución normal
# Usando un histograma
df['G3'].hist()
# Out:
# <AxesSubplot:>

# %%
# Con un gráfico de densidad
df['G3'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# Analizar para varias variables
df[['G1','G2','G3']].hist()
# Out:
# array([[<AxesSubplot:title={'center':'G1'}>,
#         <AxesSubplot:title={'center':'G2'}>],
#        [<AxesSubplot:title={'center':'G3'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df[['G1','G2','G3']].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### 2.1.6 Media<a name="2_1_6"></a>
# [Índice](#indice)

# %%
# Ver valor medio de una variable
df['G3'].mean()
# Out:
# 10.415189873417722

# %%
df['G3'].describe()
# Out:
# count    395.000000
# mean      10.415190
# std        4.581443
# min        0.000000
# 25%        8.000000
# 50%       11.000000
# 75%       14.000000
# max       20.000000
# Name: G3, dtype: float64

# %%
# Media de varias variables
df[['G1','G2','G3']].mean()
# Out:
# G1    10.908861
# G2    10.713924
# G3    10.415190
# dtype: float64

# %%
#Calcular media de notas de cada alumno -> POR FILA!!!
df['notaMedia'] = (df['G1']+df['G2']+df['G3'])/3
df[['G1','G2','G3','notaMedia']]
# Out:
#      G1  G2  G3  notaMedia
# 0     5   6   6   5.666667
# 1     5   5   6   5.333333
# 2     7   8  10   8.333333
# 3    15  14  15  14.666667
# 4     6  10  10   8.666667
# ..   ..  ..  ..        ...
# 390   9   9   9   9.000000
# 391  14  16  16  15.333333
# 392  10   8   7   8.333333
# 393  11  12  10  11.000000
# 394   8   9   9   8.666667
#
# [395 rows x 4 columns]

# %% [markdown]
# ### 2.1.7 Mediana<a name="2_1_7"></a>
# [Índice](#indice)

# %%
# Mediana
df[['G1','G2','G3']].median()
# Out:
# G1    11.0
# G2    11.0
# G3    11.0
# dtype: float64

# %%
# Mediana con función describe => Es el valor que aparece en 50%
df[['G1','G2','G3']].describe()
# Out:
#                G1          G2          G3
# count  395.000000  395.000000  395.000000
# mean    10.908861   10.713924   10.415190
# std      3.319195    3.761505    4.581443
# min      3.000000    0.000000    0.000000
# 25%      8.000000    9.000000    8.000000
# 50%     11.000000   11.000000   11.000000
# 75%     13.000000   13.000000   14.000000
# max     19.000000   19.000000   20.000000

# %% [markdown]
# ### 2.1.8 Moda<a name="2_1_8"></a>
# [Índice](#indice)

# %%
# Moda con función mode
df[['G1','G2','G3']].mode()
# Out:
#    G1  G2  G3
# 0  10   9  10

# %%
# Con value_counts
df['G3'].value_counts().idxmax()
# Out:
# 10

# %% [markdown]
# ### 2.1.9 Varianza<a name="2_1_9"></a>
# [Índice](#indice)

# %%
df.describe() # No muestra la varianza
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
df[['G1','G2','G3']].var()
# Out:
# G1    11.017053
# G2    14.148917
# G3    20.989616
# dtype: float64

# %%
#CALCULAR LA VARIANZA DE G3 A MANO
#Obtener diferencias de G3 a la media y elevarlo al 2
df['diferencias2'] = (df['G3']-df['G3'].mean())**2
print(f"media:{df['G3'].mean()}")
df[['G3','diferencias2']]
# Out:
# media:10.415189873417722
#      G3  diferencias2
# 0     6     19.493902
# 1     6     19.493902
# 2    10      0.172383
# 3    15     21.020484
# 4    10      0.172383
# ..   ..           ...
# 390   9      2.002762
# 391  16     31.190104
# 392   7     11.663522
# 393  10      0.172383
# 394   9      2.002762
#
# [395 rows x 2 columns]

# %%
#Sumamos los cuadrados
suma = df['diferencias2'].sum()
suma
# Out:
# 8269.908860759493

# %%
#Dividios entre el nº de filas (Hay otra forma que divide entre el nº filas-1)
varianza = suma/len(df)
varianza
# Out:
# 20.936478128505044

# %% [markdown]
# ### 2.1.10 Desviación Típica/Estándar<a name="2_1_10"></a>
# [Índice](#indice)

# %%
# Es la raíz cuadrada de la varianza
print(f"Desviación:{df['G3'].std()}")
print(f"\nDesviación:{df['G3'].var()**0.5}")

import math
print(f"\nDesviación:{math.sqrt(df['G3'].var())}")
# Out:
# Desviación:4.5814426109978434
#
# Desviación:4.5814426109978434
#
# Desviación:4.5814426109978434

# %%
# Desviación -> std
df[['G1','G2','G3']].describe()
# Out:
#                G1          G2          G3
# count  395.000000  395.000000  395.000000
# mean    10.908861   10.713924   10.415190
# std      3.319195    3.761505    4.581443
# min      3.000000    0.000000    0.000000
# 25%      8.000000    9.000000    8.000000
# 50%     11.000000   11.000000   11.000000
# 75%     13.000000   13.000000   14.000000
# max     19.000000   19.000000   20.000000

# %% [markdown]
# ### 2.1.11 Quartiles<a name="2_1_11"></a>
# [Índice](#indice)

# %%
# Con describe 25%=> Q1 50%=>Q2 y 75% => Q3
df[['G1','G2','G3']].describe()
# Out:
#                G1          G2          G3
# count  395.000000  395.000000  395.000000
# mean    10.908861   10.713924   10.415190
# std      3.319195    3.761505    4.581443
# min      3.000000    0.000000    0.000000
# 25%      8.000000    9.000000    8.000000
# 50%     11.000000   11.000000   11.000000
# 75%     13.000000   13.000000   14.000000
# max     19.000000   19.000000   20.000000

# %%
# Con percentiles
Q1=df['G3'].quantile(0.25) # Percentil 25
Q2=df['G3'].quantile(0.50) # Percentil 50
Q3=df['G3'].quantile(0.75) # Percentil 75
print(f"Cuartiles de G3:\n")
print(f"Q1:{Q1}\nQ2:{Q2}\nQ3:{Q3}")
# Out:
# Cuartiles de G3:
#
# Q1:8.0
# Q2:11.0
# Q3:14.0

# %%
# Diagrama de cajas y bigotes de pandas
df[['G1','G2','G3']].plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
# Con seaborn
sns.boxplot(data=df[['G1','G2','G3']])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 2.1.12 Rango Intercuartílico<a name="2_1_12"></a>
# [Índice](#indice)

# %%
# PARA G3
# IQR = Q3 - Q1
# Sirve para determinar los límites máximos y mínimos
# a partir de los cuales están los valores atípicos o outliers
IQR = Q3-Q1
print(f"IQR:{IQR}")
max = Q3+(IQR*1.5)
print(f"Máximum:{max}")
min = Q1-(IQR*1.5)
print(f"Mínimu:{min}")
# Out:
# IQR:6.0
# Máximum:23.0
# Mínimu:-1.0

# %%
df['G3'].value_counts().sort_index()
# Máximum 23, pero el límite superior del diagrama está en 20
# Mínimu -1, pero el límite inferior del diagrama está en 0
# Out:
# 0     38
# 4      1
# 5      7
# 6     15
# 7      9
# 8     32
# 9     28
# 10    56
# 11    47
# 12    31
# 13    31
# 14    27
# 15    33
# 16    16
# 17     6
# 18    12
# 19     5
# 20     1
# Name: G3, dtype: int64

# %%
# boxplot de G3
sns.boxplot(data=df[['G3']])
# Importar pyplot de matplotlib
plt.title('Análsis de G3')
plt.axhline(y=max, color='r') # Pintar línea en máximo
plt.axhline(y=min, color='r') # Pintar línea en mínimo

# %%
# PARA G2 
# IQR = Q3 - Q1
# Sirve para determinar los límites máximos y mínimos
# a partir de los cuales están los valores atípicos o outliers
Q3_g2=df['G2'].quantile(0.75)
Q1_g2=df['G2'].quantile(0.25)
IQR_g2 = Q3_g2-Q1_g2
print(f"Q1 G2:{Q1_g2}")
print(f"Q3 G2:{Q3_g2}")
print(f"IQR G2:{IQR_g2}")
max_g2 = Q3_g2+(IQR_g2*1.5)
print(f"Máximum G2:{max_g2}")
min_g2 = Q1_g2-(IQR_g2*1.5)
print(f"Mínimum:{min_g2}")
# Out:
# Q1 G2:9.0
# Q3 G2:13.0
# IQR G2:4.0
# Máximum G2:19.0
# Mínimu:3.0

# %%
df['G2'].value_counts().sort_index()
# Máximum 1 y el límite superior del diagrama está en 19
# Mínimum 3, pero el límite inferior del diagrama está en 4
# Out:
# 0     13
# 4      1
# 5     15
# 6     14
# 7     21
# 8     32
# 9     50
# 10    46
# 11    35
# 12    41
# 13    37
# 14    23
# 15    34
# 16    13
# 17     5
# 18    12
# 19     3
# Name: G2, dtype: int64

# %%
# boxplot de G3
sns.boxplot(data=df[['G2']])
# Importar pyplot de matplotlib
plt.title('Análsis de G2')
plt.axhline(y=max_g2, color='r') # Pintar línea en máximo
plt.axhline(y=min_g2, color='r') # Pintar línea en mínimo

# %% [markdown]
# ## 2.2. Detección de outliers<a name="2_2"></a>
# [Índice](#indice)

# %%
# Para detectar outliers podemos 
# usar los boxplot o los diagramas de dispersión
# Diagrama de dispersión con pandas
df.reset_index().plot.scatter(x='index',y='G3',color='r',
                              title='Gráfico de dispersión de G3')
# Dibujar línea de máximum y mínimum según IQR
plt.axhline(y=min, color='b',label='Mínimum')
plt.axhline(y=max, color='g',label='Máximum')
plt.legend()

# %%
# Gráfica de dispersión de G2 con seaborn
sns.scatterplot(data=df,x=df.index,y='G2').set(title='Diagrama dispersión de G2')
# Dibujar línea de máximum y mínimum según IQR
plt.axhline(y=min_g2, color='b',label='Mínimum')
plt.axhline(y=max_g2, color='g',label='Máximum')
plt.legend()

# %%
# Gráfica de dispersión de G2 con seaborn, distinguiendo por sexo
#plt.figure(figsize=(10,10)) #Damos tamaño al gráfico
sns.scatterplot(data=df,x=df.index,y='G2',hue='age',palette="deep").set(title="Diagrama dispersión de G2")
# Dibujar línea de máximum y mínimum según IQR
plt.axhline(y=min_g2, color='b')
plt.axhline(y=max_g2, color='g')
plt.legend()

# %% [markdown]
# ## 2.3 Detección de correlaciones<a name="2_3"></a>
# [Índice](#indice)

# %%
# Estudio de correlación de dos variables con pandas
# Correlación de edad con G3
df.plot.scatter(x='age',y='G3',title='Correlación de edad con G3', color='b')
# Out:
# <AxesSubplot:title={'center':'Correlación de edad con G3'}, xlabel='age', ylabel='G3'>

# %%
# Estudio de correlación de dos variables con pandas
# Correlación de G2 con G3
df.plot.scatter(x='G2',y='G3',title='Correlación de G2 con G3', color='b')
# Out:
# <AxesSubplot:title={'center':'Correlación de G2 con G3'}, xlabel='G2', ylabel='G3'>

# %%
# Estudio de correlación de dos variables con seaborn
# Correlación de edad con G3
sns.scatterplot(data=df, x='age',y='G3').set(title='Correlación de edad con G3',)
# Out:
# [Text(0.5, 1.0, 'Correlación de edad con G3')]

# %%
# Estudio de correlación de dos variables con seaborn
# Correlación de G2 con G3 diferenciando entre hombres y mujeres
sns.scatterplot(data=df, x='G2',y='G3',hue='sex').set(title='Correlación de edad con G3',)
# Out:
# [Text(0.5, 1.0, 'Correlación de edad con G3')]

# %%
#Matriz de diagramas de dispersión con pandas, diagonal con histogramas
pd.plotting.scatter_matrix(df,figsize=(20,20))
# Out:
# array([[<AxesSubplot:xlabel='age', ylabel='age'>,
#         <AxesSubplot:xlabel='Medu', ylabel='age'>,
#         <AxesSubplot:xlabel='Fedu', ylabel='age'>,
#         <AxesSubplot:xlabel='traveltime', ylabel='age'>,
#         <AxesSubplot:xlabel='studytime', ylabel='age'>,
#         <AxesSubplot:xlabel='failures', ylabel='age'>,
#         <AxesSubplot:xlabel='famrel', ylabel='age'>,
#         <AxesSubplot:xlabel='freetime', ylabel='age'>,
#         <AxesSubplot:xlabel='goout', ylabel='age'>,
#         <AxesSubplot:xlabel='Dalc', ylabel='age'>,
#         <AxesSubplot:xlabel='Walc', ylabel='age'>,
#         <AxesSubplot:xlabel='health', ylabel='age'>,
#         <AxesSubplot:xlabel='absences', ylabel='age'>,
#         <AxesSubplot:xlabel='G1', ylabel='age'>,
#         <AxesSubplot:xlabel='G2', ylabel='age'>,
#         <AxesSubplot:xlabel='G3', ylabel='age'>,
#         <AxesSubplot:xlabel='notaMedia', ylabel='age'>,
#         <AxesSubplot:xlabel='diferencias2', ylabel='age'>],
# ...

# %%
#Matriz de diagramas de dispersión con pandas, diagonal con diagrama de densidad
pd.plotting.scatter_matrix(df,figsize=(20,20),diagonal='kde')
# Out:
# array([[<AxesSubplot:xlabel='age', ylabel='age'>,
#         <AxesSubplot:xlabel='Medu', ylabel='age'>,
#         <AxesSubplot:xlabel='Fedu', ylabel='age'>,
#         <AxesSubplot:xlabel='traveltime', ylabel='age'>,
#         <AxesSubplot:xlabel='studytime', ylabel='age'>,
#         <AxesSubplot:xlabel='failures', ylabel='age'>,
#         <AxesSubplot:xlabel='famrel', ylabel='age'>,
#         <AxesSubplot:xlabel='freetime', ylabel='age'>,
#         <AxesSubplot:xlabel='goout', ylabel='age'>,
#         <AxesSubplot:xlabel='Dalc', ylabel='age'>,
#         <AxesSubplot:xlabel='Walc', ylabel='age'>,
#         <AxesSubplot:xlabel='health', ylabel='age'>,
#         <AxesSubplot:xlabel='absences', ylabel='age'>,
#         <AxesSubplot:xlabel='G1', ylabel='age'>,
#         <AxesSubplot:xlabel='G2', ylabel='age'>,
#         <AxesSubplot:xlabel='G3', ylabel='age'>,
#         <AxesSubplot:xlabel='notaMedia', ylabel='age'>,
#         <AxesSubplot:xlabel='diferencias2', ylabel='age'>],
# ...

# %% [markdown]
# # 3 Diseño de características<a name="3"></a>
# [Índice](#indice)

# %% [markdown]
# ## 3.1 Tratamiento de datos nulos<a name="3_1"></a>
# [Índice](#indice)

# %% [markdown]
# ## 3.2 Transformación de características<a name="3_2"></a>
# [Índice](#indice)

# %% [markdown]
# ## 3.3 Selección de características relevante<a name="3_3"></a>
# [Índice](#indice)

# %% [markdown]
# ## 3.4 Tratamiento de outliers<a name="3_4"></a>
# [Índice](#indice)

# %% [markdown]
# ## 3.5 Tratamiento de correlación<a name="3_5"></a>
# [Índice](#indice)

# %% [markdown]
# ## 3.6 Normalización<a name="3_6"></a>
# [Índice](#indice)
